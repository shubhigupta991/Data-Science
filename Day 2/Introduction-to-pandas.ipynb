# %%
import pandas as pd

# %% [markdown]
# # Creating Series
# Series are 1-dimensional

# %%
series = pd.Series(['BMW','Toyota','Honda'])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
color = pd.Series(['Black','White','Red'])

# %% [markdown]
# # Creating DataFrames
# Dataframes are 2-dimensional

# %%
dataFrame= pd.DataFrame({'Make':series,'Color':color})

# %%
dataFrame
# Out:
#      Make  Color
# 0     BMW  Black
# 1  Toyota  White
# 2   Honda    Red

# %% [markdown]
# # Importing Data

# %%
Car_sales = pd.read_csv('car-sales.csv')

# %%
Car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Exporting Data

# %%
Car_sales.to_csv('export_car_sales.csv', index = False)

# %%
export_Car_sales = pd.read_csv('export_car_sales.csv')

# %%
export_Car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00
