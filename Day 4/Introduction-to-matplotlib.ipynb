# %%
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();                         #removes empty brackets

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)

# %%
plt.plot(y,x)

# %%
# 1st method
fig = plt.figure()         #creates figure
ax = fig.add_subplot()     #add some axes
plt.show()

# %%
#2nd method
fig = plt.figure()        #creates figure
ax = fig.add_axes([1,1,1,1])       #add axes
ax.plot(x,y)            #add data
plt.show()

# %%
#3rd method(recommended)
fig,ax = plt.subplots()
ax.plot(x,y)
plt.show()

# %% [markdown]
# # Matplotlib WorkFlow

# %%
#0.import matplotlib and get it ready for jupiter notebook
import matplotlib.pyplot as plt

#1.Prepare Data
x = [1,2,3,4,5]
y = [10,20,30,40,50]

#2.Setup plot
fig,ax = plt.subplots(figsize = (10,10))               #(width,height)

#3.Plot data 
ax.plot(x,y)

#4.Customize plot
ax.set(title = 'Sample Plot', ylabel = 'y-axis', xlabel = 'x axis')

#Sav and show
fig.savefig('sample plot.png')
